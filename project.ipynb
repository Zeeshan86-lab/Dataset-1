# %%
import pandas as pd

# %%
import matplotlib as plt

# %%
data=pd.read_csv("zeeshan.csv")
data
# Out:
#               country  MostVisited_NumOfArrivalsPredictive_Millions_2024  \
# 0               India                                               17.9
# 1               China                                               65.7
# 2       United States                                               79.3
# 3           Indonesia                                               15.5
# 4            Pakistan                                                NaN
# ..                ...                                                ...
# 198            Monaco                                                NaN
# 199  Marshall Islands                                                NaN
# 200        San Marino                                                NaN
# 201             Palau                                                NaN
# 202            Tuvalu                                                NaN
#
#      MostVisited_NumOfArrivals_Millions_2023  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 203 entries, 0 to 202
# Data columns (total 6 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   country                                            203 non-null    object
#  1   MostVisited_NumOfArrivalsPredictive_Millions_2024  50 non-null     float64
#  2   MostVisited_NumOfArrivals_Millions_2023            49 non-null     float64
#  3   MostVisited_NumOfArrivals_Millions_2022            20 non-null     float64
#  4   MostVisited_NumOfArrivals_WorldBank                202 non-null    float64
#  5   MostVisited_DataYear_WorldBank                     202 non-null    float64
# dtypes: float64(5), object(1)
# memory usage: 9.6+ KB

# %%
data.head(3)
# Out:
#          country  MostVisited_NumOfArrivalsPredictive_Millions_2024  \
# 0          India                                               17.9
# 1          China                                               65.7
# 2  United States                                               79.3
#
#    MostVisited_NumOfArrivals_Millions_2023  \
# 0                                      NaN
# 1                                      NaN
# 2                                    66.48
#
#    MostVisited_NumOfArrivals_Millions_2022  \
# 0                                      NaN
# 1                                      NaN
# 2                                    50.87
#
#    MostVisited_NumOfArrivals_WorldBank  MostVisited_DataYear_WorldBank
# 0                           17914000.0                          2019.0
# 1                           30402000.0                          2020.0
# 2                           45037000.0                          2020.0

# %%
data.tail(6)
# Out:
#                     country  \
# 197  British Virgin Islands
# 198                  Monaco
# 199        Marshall Islands
# 200              San Marino
# 201                   Palau
# 202                  Tuvalu
#
#      MostVisited_NumOfArrivalsPredictive_Millions_2024  \
# 197                                                NaN
# 198                                                NaN
# 199                                                NaN
# 200                                                NaN
# 201                                                NaN
# 202                                                NaN
#
#      MostVisited_NumOfArrivals_Millions_2023  \
# 197                                      NaN
# 198                                      NaN
# 199                                      NaN
# 200                                      NaN
# 201                                      NaN
# 202                                      NaN
#
# ...

# %%
data.sample(5)
# Out:
#         country  MostVisited_NumOfArrivalsPredictive_Millions_2024  \
# 142    Slovenia                                                NaN
# 47   Madagascar                                                NaN
# 116        Oman                                                NaN
# 135     Jamaica                                                NaN
# 90       Greece                                               31.3
#
#      MostVisited_NumOfArrivals_Millions_2023  \
# 142                                      NaN
# 47                                       NaN
# 116                                      NaN
# 135                                      NaN
# 90                                     32.74
#
#      MostVisited_NumOfArrivals_Millions_2022  \
# 142                                      NaN
# 47                                       NaN
# 116                                      NaN
# 135                                      NaN
# 90                                     27.84
#
# ...

# %%
data.shape
# Out:
# (203, 6)

# %%
data.rename(columns={"Thialand":"pakistan","America":"Scotland"})
# Out:
#               country  MostVisited_NumOfArrivalsPredictive_Millions_2024  \
# 0               India                                               17.9
# 1               China                                               65.7
# 2       United States                                               79.3
# 3           Indonesia                                               15.5
# 4            Pakistan                                                NaN
# ..                ...                                                ...
# 198            Monaco                                                NaN
# 199  Marshall Islands                                                NaN
# 200        San Marino                                                NaN
# 201             Palau                                                NaN
# 202            Tuvalu                                                NaN
#
#      MostVisited_NumOfArrivals_Millions_2023  \
# ...

# %%
data.describe()
# Out:
#        MostVisited_NumOfArrivalsPredictive_Millions_2024  \
# count                                          50.000000
# mean                                           24.102000
# std                                            20.915374
# min                                             5.900000
# 25%                                             9.750000
# 50%                                            16.800000
# 75%                                            30.000000
# max                                            89.400000
#
#        MostVisited_NumOfArrivals_Millions_2023  \
# count                                 49.00000
# mean                                  19.22898
# std                                   20.78654
# min                                    3.73000
# 25%                                    5.87000
# 50%                                   11.03000
# 75%                                   26.54000
# max                                  100.00000
#
# ...

# %%
data.notnull()
# Out:
#      country  MostVisited_NumOfArrivalsPredictive_Millions_2024  \
# 0       True                                               True
# 1       True                                               True
# 2       True                                               True
# 3       True                                               True
# 4       True                                              False
# ..       ...                                                ...
# 198     True                                              False
# 199     True                                              False
# 200     True                                              False
# 201     True                                              False
# 202     True                                              False
#
#      MostVisited_NumOfArrivals_Millions_2023  \
# 0                                      False
# 1                                      False
# 2                                       True
# ...

# %%
data.dtypes
# Out:
# country                                               object
# MostVisited_NumOfArrivalsPredictive_Millions_2024    float64
# MostVisited_NumOfArrivals_Millions_2023              float64
# MostVisited_NumOfArrivals_Millions_2022              float64
# MostVisited_NumOfArrivals_WorldBank                  float64
# MostVisited_DataYear_WorldBank                       float64
# dtype: object

# %%
data.columns
# Out:
# Index(['country', 'MostVisited_NumOfArrivalsPredictive_Millions_2024',
#        'MostVisited_NumOfArrivals_Millions_2023',
#        'MostVisited_NumOfArrivals_Millions_2022',
#        'MostVisited_NumOfArrivals_WorldBank',
#        'MostVisited_DataYear_WorldBank'],
#       dtype='object')

# %%
data[1:7:2]
# Out:
#      country  MostVisited_NumOfArrivalsPredictive_Millions_2024  \
# 1      China                                               65.7
# 3  Indonesia                                               15.5
# 5    Nigeria                                                NaN
#
#    MostVisited_NumOfArrivals_Millions_2023  \
# 1                                      NaN
# 3                                      NaN
# 5                                      NaN
#
#    MostVisited_NumOfArrivals_Millions_2022  \
# 1                                      NaN
# 3                                      NaN
# 5                                      NaN
#
#    MostVisited_NumOfArrivals_WorldBank  MostVisited_DataYear_WorldBank
# 1                           30402000.0                          2020.0
# 3                            4053000.0                          2020.0
# 5                            5265000.0                          2016.0

# %%
data[2:5]
# Out:
#          country  MostVisited_NumOfArrivalsPredictive_Millions_2024  \
# 2  United States                                               79.3
# 3      Indonesia                                               15.5
# 4       Pakistan                                                NaN
#
#    MostVisited_NumOfArrivals_Millions_2023  \
# 2                                    66.48
# 3                                      NaN
# 4                                      NaN
#
#    MostVisited_NumOfArrivals_Millions_2022  \
# 2                                    50.87
# 3                                      NaN
# 4                                      NaN
#
#    MostVisited_NumOfArrivals_WorldBank  MostVisited_DataYear_WorldBank
# 2                           45037000.0                          2020.0
# 3                            4053000.0                          2020.0
# 4                             966000.0                          2012.0

# %%
data.dropna()
# Out:
#                  country  MostVisited_NumOfArrivalsPredictive_Millions_2024  \
# 2          United States                                               79.3
# 10                Mexico                                               45.0
# 12                 Egypt                                               11.3
# 18               Germany                                               39.6
# 20        United Kingdom                                               39.4
# 22                France                                               89.4
# 24                 Italy                                               64.5
# 31                 Spain                                               83.7
# 36                Canada                                               22.1
# 37                Poland                                               22.1
# 46          Saudi Arabia                                               13.6
# ...

# %%
data.fillna(3)
# Out:
#               country  MostVisited_NumOfArrivalsPredictive_Millions_2024  \
# 0               India                                               17.9
# 1               China                                               65.7
# 2       United States                                               79.3
# 3           Indonesia                                               15.5
# 4            Pakistan                                                3.0
# ..                ...                                                ...
# 198            Monaco                                                3.0
# 199  Marshall Islands                                                3.0
# 200        San Marino                                                3.0
# 201             Palau                                                3.0
# 202            Tuvalu                                                3.0
#
#      MostVisited_NumOfArrivals_Millions_2023  \
# ...

# %%
data.loc[[2,5,7,11]]
# Out:
#           country  MostVisited_NumOfArrivalsPredictive_Millions_2024  \
# 2   United States                                               79.3
# 5         Nigeria                                                NaN
# 7      Bangladesh                                                NaN
# 11          Japan                                               32.3
#
#     MostVisited_NumOfArrivals_Millions_2023  \
# 2                                     66.48
# 5                                       NaN
# 7                                       NaN
# 11                                    25.07
#
#     MostVisited_NumOfArrivals_Millions_2022  \
# 2                                     50.87
# 5                                       NaN
# 7                                       NaN
# 11                                      NaN
#
#     MostVisited_NumOfArrivals_WorldBank  MostVisited_DataYear_WorldBank
# 2                            45037000.0                          2020.0
# ...

# %%
data.isnull().sum()
# Out:
# country                                                0
# MostVisited_NumOfArrivalsPredictive_Millions_2024    153
# MostVisited_NumOfArrivals_Millions_2023              154
# MostVisited_NumOfArrivals_Millions_2022              183
# MostVisited_NumOfArrivals_WorldBank                    1
# MostVisited_DataYear_WorldBank                         1
# dtype: int64

# %%
data[data["country"].isnull()]
# Out:
# Empty DataFrame
# Columns: [country, MostVisited_NumOfArrivalsPredictive_Millions_2024, MostVisited_NumOfArrivals_Millions_2023, MostVisited_NumOfArrivals_Millions_2022, MostVisited_NumOfArrivals_WorldBank, MostVisited_DataYear_WorldBank]
# Index: []

# %%
data.head()
# Out:
#          country  MostVisited_NumOfArrivalsPredictive_Millions_2024  \
# 0          India                                               17.9
# 1          China                                               65.7
# 2  United States                                               79.3
# 3      Indonesia                                               15.5
# 4       Pakistan                                                NaN
#
#    MostVisited_NumOfArrivals_Millions_2023  \
# 0                                      NaN
# 1                                      NaN
# 2                                    66.48
# 3                                      NaN
# 4                                      NaN
#
#    MostVisited_NumOfArrivals_Millions_2022  \
# 0                                      NaN
# 1                                      NaN
# 2                                    50.87
# 3                                      NaN
# 4                                      NaN
#
# ...

# %%
data["country"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='country'>

# %%
data["country"].value_counts().plot(kind="line")
# Out:
# <Axes: xlabel='country'>

# %%
data["country"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
data["country"].value_counts().plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
data.plot(color='red')
# Out:
# <Axes: >

# %%
data["MostVisited_NumOfArrivals_Millions_2023"].mean()
# Out:
# 19.228979591836737

# %%
data["MostVisited_NumOfArrivals_Millions_2023"].median()
# Out:
# 11.03

# %%
data["MostVisited_NumOfArrivals_Millions_2023"].mode()
# Out:
# 0     4.05
# 1    28.15
# Name: MostVisited_NumOfArrivals_Millions_2023, dtype: float64
